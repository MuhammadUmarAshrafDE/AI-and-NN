# %%
import pandas as pd
import numpy as np

# %%
# creating 4 neurons

input = [1.3,2.4,3.6,-1.8]
w1=[0.2,0.8,-0.5,0.3]
w2=[0.5,-0.84,0.53,-0.3]
w3=[-0.21,-0.62,0.16,0.78]
b1=2
b2=4
b3=0.8

# %%
#Neuron 1
output = input[0]*w1[0]+input[1]*w1[1]+input[2]*w1[2]+input[3]*w1[3]+  b1
print(output)
# Out:
# 1.8399999999999996
